# %% [markdown]
# <a href="https://colab.research.google.com/github/meganalvord/CodingFellows_sandbox/blob/main/quarknetworkshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Stuff from the QuarkNet Virtual Center meet up workshop in Albuquerque, NM
# July 31, 2024

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([-3,-2,-1,0,1,2,3])
y = np.array([-.0335, -0.0205, -0.008,0, 0.008,0.0205,0.0335])

a,b = np.polyfit(x,y,deg=1)

plt.scatter(x,y)
plt.plot(x,a*x+b)
plt.xlabel('wave number')
plt.ylabel('peak location (m)')
plt.text(-2, 0.02, f'y = {b:.5f} + {a:.5f}m * m', size=14)
plt.show()

# %%
d = 0.3e-3 #m
L = 2.95 #m

wavelength = a*d/L
print(wavelength, ' m')
# Out:
# 1.0859564164648912e-06  m

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4.539,5.076,5.310,6.383])*10**14
y = np.array([1.45025,1.5815,1.947,2.04])
y_J = y*1.6e-19

a,b = np.polyfit(x,y_J,deg=1)

plt.scatter(x,y_J)
plt.plot(x,a*x+b)
plt.xlabel('frequency (Hz)')
plt.ylabel('Energy (J)')
plt.title('Planck’s Constant Measured from LED Observations')
plt.text(5.5e14, 2.5e-19, f'E = {a:.3e}Js* f + {b:.3e}J', size=14)
plt.show()
print(f'E = {a:.3e}Js* f + {b:.3e}J')
# Out:
# E = 5.170e-34Js* f + 5.360e-21J

# %%
print('experimental slope = ', a, 'Js')
expected = 6.62607015e-34
print('expected slope = ',expected,' Js')
percenterror = np.abs(a - expected)/expected * 100
print('percent error = ',percenterror,'%')
# Out:
# experimental slope =  5.169698283288037e-34 Js
# expected slope =  6.62607015e-34  Js
# percent error =  21.979421191488036 %

# %%
import pandas as pd

data = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vT3nrYEsIyx3NN8mf3BvwWemVzVPrWmE2hFgvdPwdMy5fZxm-VPU9PV0p-mTsQBt4LbYG-kCwo4_HT2/pub?gid=760622037&single=true&output=csv')

# %%
a1,b1 = np.polyfit(data['Momentum (kg m/s)'],data['Work (J)'],deg=1)

plt.scatter(data['Momentum (kg m/s)'],data['Work (J)'])
plt.plot(data['Momentum (kg m/s)'],a1*data['Momentum (kg m/s)']+b1)
plt.xlabel('momentum (kg m/s)')
plt.ylabel('Work (J)')
#plt.title('Planck’s Constant Measured from LED Observations')
#plt.text(5.5e14, 2.5e-19, f'E = {a:.3e}Js* f + {b:.3e}J', size=14)
plt.show()

print('slope = ',a1)
# Out:
# slope =  11399783.315276273

# %%
a2,b2 = np.polyfit(data['Speed (m/s)'],data['Work (J)'],deg=1)

plt.scatter(data['Speed (m/s)'],data['Work (J)'])
plt.plot(data['Speed (m/s)'],a2*data['Speed (m/s)']+b2)
plt.xlabel('Speed (m/s)')
plt.ylabel('Work (J)')
#plt.title('Planck’s Constant Measured from LED Observations')
#plt.text(5.5e14, 2.5e-19, f'E = {a:.3e}Js* f + {b:.3e}J', size=14)
plt.show()

print('slope = ',a2)
# Out:
# slope =  1.0384377233308847e-23

# %%
new_wave = data['Wavelength (nm)']*10**-9
a3,b3 = np.polyfit(new_wave,data['Work (J)'],deg=1)

plt.scatter(new_wave,data['Work (J)'])
plt.plot(new_wave,a3*new_wave+b3)
plt.xlabel('Wavelength (m)')
plt.ylabel('Work (J)')
#plt.title('Planck’s Constant Measured from LED Observations')
#plt.text(5.5e14, 2.5e-19, f'E = {a:.3e}Js* f + {b:.3e}J', size=14)
plt.show()

print('slope = ',a3)
# Out:
# slope =  -6.955974313038166e-05

# %%
new_wave = data['Wavelength (nm)']*10**-9
a4,b4 = np.polyfit(data['Inverse momentum'],new_wave,deg=1)

plt.scatter(data['Inverse momentum'],new_wave)
plt.plot(data['Inverse momentum'],a4*data['Inverse momentum']+b4)
plt.ylabel('Wavelength (m)')
plt.xlabel('inverse momentum (kgm/s)^-1')
#plt.title('Planck’s Constant Measured from LED Observations')
#plt.text(5.5e14, 2.5e-19, f'E = {a:.3e}Js* f + {b:.3e}J', size=14)
plt.show()

print('slope = ',a4)
# Out:
# slope =  1.6906981748801938e-33

# %%
delta_p = np.array([6.87, 14.73,19.47,5.73,11.03]) #mm, width of central maximum
delta_x = np.array([0.72, 0.55,0.43,0.83,0.6]) #mm, width of caliper single slit

a5,b5 = np.polyfit(delta_x,delta_p,deg=1)

plt.scatter(delta_x,delta_p)
plt.plot(delta_x,a5*delta_x+b5)

plt.xlabel('Width of slit - uncertainty in position')
plt.ylabel('Width of central max - uncertainty in momentum')
#plt.title('Planck’s Constant Measured from LED Observations')
#plt.text(5.5e14, 2.5e-19, f'E = {a:.3e}Js* f + {b:.3e}J', size=14)
plt.show()

print('slope = ',a5)
# Out:
# slope =  -35.74989509022241

# %%
central_max = np.array([6.87, 14.73,19.47,5.73,11.03]) #mm, width of central maximum
central_max_m = central_max*10**-3 #m

D = 2.03 #m distance to screen
h = 6.62e-34 #Js
wavelength = 650e-9 #m

delta_p = (central_max_m*h)/(2*D*wavelength) #kgm/s

delta_x = np.array([0.72, 0.55,0.43,0.83,0.6]) #mm, width of caliper single slit

a6,b6 = np.polyfit(delta_x,delta_p,deg=1)

plt.scatter(delta_x,delta_p)
plt.plot(delta_x,a6*delta_x+b6)

plt.xlabel('Uncertainty in position (m)')
plt.ylabel('Uncertainty in momentum')
#plt.title('Planck’s Constant Measured from LED Observations')
#plt.text(5.5e14, 2.5e-19, f'E = {a:.3e}Js* f + {b:.3e}J', size=14)
plt.show()

print('slope = ',a6)
# Out:
# slope =  -8.967953978676478e-30
# hbar =  5.268028616341736e-35

# %%
central_max = np.array([6.87, 14.73,19.47,5.73,11.03]) #mm, width of central maximum
central_max_m = central_max*10**-3 #m

D = 2.03 #m distance to screen
h = 6.62e-34 #Js
wavelength = 650e-9 #m

delta_p = (0.5*central_max_m*h)/(2*D*wavelength) #kgm/s

delta_x = np.array([0.72, 0.55,0.43,0.83,0.6]) #mm, width of caliper single slit
delta_x_m = delta_x*10**-3 #m
inverse_delta_x = 1/delta_x_m

a7,b7 = np.polyfit(inverse_delta_x,delta_p,deg=1)

plt.scatter(inverse_delta_x,delta_p)
plt.plot(inverse_delta_x,a7*inverse_delta_x+b7)

plt.xlabel('Inverse Uncertainty in position (1/m)')
plt.ylabel('Uncertainty in momentum (kgm/s)')
#plt.title('Planck’s Constant Measured from LED Observations')
#plt.text(5.5e14, 2.5e-19, f'E = {a:.3e}Js* f + {b:.3e}J', size=14)
plt.show()

print('slope = ',a7)
expected = h / (4*np.pi)
print('expected slope = ',h)

print('intercept = ',b7)
# Out:
# slope =  1.6274540045344e-33
# expected slope =  6.62e-34
# intercept =  -1.284789062769383e-30
